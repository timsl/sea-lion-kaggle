# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
# %matplotlib inline
#%matplotlib qt

# %%
img = mpimg.imread('Train/0.jpg')
imgplot = plt.imshow(img)

# %%
img_dotted = mpimg.imread('TrainDotted/0.jpg')
imgplot = plt.imshow(img_dotted)

# %%
img_dots = cv2.subtract(img, img_dotted)
img_dots = img_dots/img_dots.max()
img_dots[img_dotted < 20] = 0
imgplot = plt.imshow(img_dots)

# %%
coords
